# %%
print ('Hello World')
# Out:
# Hello World

# %% [markdown]
# # Data Types

# %% [markdown]
# ## Integers

# %%
x = 42
print (x)
# Out:
# 42

# %%
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ## Floating Point Number

# %%
a = 3.14
b = 5.87

c = a = b

# %%
c
# Out:
# 5.87

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
a = 5
b = 2
div1 = a/b
div2 = a//b
div3 = a%b

# %%
print(f"Simple devision: {div1}")
print(f"Integer division: {div2}")
print(f"Remendent: {div3}")
# Out:
# Simple devision: 2.5
# Integer division: 2
# Remendent: 1

# %% [markdown]
# ## Strings

# %%
f_name = "Karen"
l_name = "Hovnanyan"

# %%
full_name = f_name + " " + l_name
full_name
# Out:
# 'Karen Hovnanyan'

# %%
print(type(full_name))
# Out:
# <class 'str'>

# %%
a = '11'
a += '5'
a
# Out:
# '115'

# %%
N = 4
power = 3
for i in range(N):
    print(f'{i} power of {power} equals {i**power}')
# Out:
# 0 power of 3 equals 0
# 1 power of 3 equals 1
# 2 power of 3 equals 8
# 3 power of 3 equals 27

# %% [markdown]
# ## Boolean

# %%
is_active = True
is_complete = False
is_active
# Out:
# True

# %%
print(type(is_active))
# Out:
# <class 'bool'>

# %%
x = 10
x < 5
# Out:
# False

# %%
x = 45

# %%
x == 41
# Out:
# False

# %%
x >= 41
# Out:
# True
