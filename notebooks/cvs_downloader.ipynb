# %%
import pandas as pd

# %%
from utils import csv_downloader

# %%
URL = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/cohort/cohort_analysis.csv',
NAME = 'cohort_analysis'
PATH = '../data/cohort/'

df = csv_downloader(url = URL, name = NAME, path = PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       2 NAME = 'cohort_analysis'
#       3 PATH = '../data/cohort/'
# ----> 5 df = csv_downloader(url = URL, name = NAME, path = PATH)
#
# TypeError: csv_downloader() got an unexpected keyword argument 'url'. Did you mean 'URL'?

# %%
df = pd.read_csv(url = 'https://raw.githubusercontent.com/hovhannisyan91/data_analytics_with_python/refs/heads/main/data/cohort/cohort_analysis.csv',)
    df.to_csv(f"{path}/{name}.csv", index=False)
    print(f"{name} saved in {path} | shape: {df.shape}")
    return df
# Out:
#   Cell In[7], line 2
#     df.to_csv(f"{path}/{name}.csv", index=False)
#     ^
# IndentationError: unexpected indent

# %%
df_orders = pd.read_csv('../data/orders.csv', parse_dates = ['order_date'])
